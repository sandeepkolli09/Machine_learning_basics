# %% [markdown]
# # MultiValued Linear Regression:

# %% [markdown]
# Dataset Descriptioin :
#  The dataset contains various physical attributes of the fish and they will be used to predict the weight of the fish

# %% [markdown]
# The dataset contains the features(columns) like :
#
# 1.Species
# 2.Weight
# 3.Length1
# 4.Length2
# 5.Length3
# 6.Height
# 7.Width
#
# where the target variable is "weight" , from the dataset  the length ,width and height   are used to predict the weight of the using linear regression

# %%
import pandas as pd
from sklearn import linear_model
df=pd.read_csv("files/Fish[1].csv")     #load dataset

# %%
df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
unique_species = df['Species'].unique()

# %%
unique_species  #the unique names of the fishes
# Out:
# array(['Bream', 'Roach', 'Whitefish', 'Parkki', 'Perch', 'Pike', 'Smelt'],
#       dtype=object)

# %% [markdown]
# Here we come to know that the species of the fish has no relation ship with the weight of the fish so we can remove it

# %%
newdf=df.drop(['Species'],axis="columns")

# %%
newdf
# Out:
#      Weight  Length1  Length2  Length3   Height   Width
# 0     242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...      ...      ...      ...      ...     ...
# 154    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 6 columns]

# %% [markdown]
# let us find the realationship between the columns with ploting

# %%
import seaborn as sns

# %%
import numpy as np
import matplotlib.pyplot as plt
# slope,intter=np.polyfit('Length1','Weight',1)

# %%
sns.scatterplot(x='Length1',y='Weight',data=df)
# Out:
# <Axes: xlabel='Length1', ylabel='Weight'>

# %%
sns.scatterplot(x='Length2',y='Weight',data=df)
# Out:
# <Axes: xlabel='Length2', ylabel='Weight'>

# %%
sns.scatterplot(x='Height',y='Weight',data=f)
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
sns.scatterplot(x='Length3',y='Weight',data=f)
# Out:
# <Axes: xlabel='Length3', ylabel='Weight'>

# %% [markdown]
# here we have no outliers and duplicates and we have the data which is directly propotional so we can directly apply  on it

# %%
from sklearn import linear_model
model=linear_model.LinearRegression()

# %%
new=f.drop(['Weight','Species'],axis='columns')
new
weight=f.Weight
weight
# Out:
# 0      242.0
# 1      290.0
# 2      340.0
# 3      363.0
# 4      430.0
#        ...
# 154     12.2
# 155     13.4
# 156     12.2
# 157     19.7
# 158     19.9
# Name: Weight, Length: 159, dtype: float64

# %%
new
# Out:
#      Length1  Length2  Length3   Height   Width
# 0       23.2     25.4     30.0  11.5200  4.0200
# 1       24.0     26.3     31.2  12.4800  4.3056
# 2       23.9     26.5     31.1  12.3778  4.6961
# 3       26.3     29.0     33.5  12.7300  4.4555
# 4       26.5     29.0     34.0  12.4440  5.1340
# ..       ...      ...      ...      ...     ...
# 154     11.5     12.2     13.4   2.0904  1.3936
# 155     11.7     12.4     13.5   2.4300  1.2690
# 156     12.1     13.0     13.8   2.2770  1.2558
# 157     13.2     14.3     15.2   2.8728  2.0672
# 158     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 5 columns]

# %%
x=new

# %%
from sklearn.model_selection import train_test_split

# %%
x_t,x_te,y_tr,y_t=train_test_split(x,weight,test_size=0.2)

# %%
model.fit(x_t,y_tr)
# Out:
# LinearRegression()

# %%
model.predict(x_te)
# Out:
# array([ 669.11940997,   19.7637352 ,  642.02144788, 1098.81280952,
#         170.33140777,  739.9179862 ,  221.58682675,  916.73807241,
#         931.19742894,   73.45121205, -193.44556738, -190.91319183,
#         397.29910661,  592.40362421,  374.44200205, -215.3578526 ,
#         647.26919383,  520.08959539,   83.24173074,  571.43224306,
#         563.59245145,  210.5059867 ,  130.83498422, -190.17432596,
#        1070.72167128,  852.08059397,  336.93951775,  158.22428069,
#         719.93653108,   89.99110453,  702.72231012,  425.4480658 ])

# %%
model.score(x_t,y_tr)
# Out:
# 0.8824141504611128

# %%
fog.fit(f[['Length1','Length2','Length3','Height','Width']],weight)
# Out:
# LinearRegression()

# %%
model.predict([[23.2,25.4,30.0,11.5200,4.0200]])
# Out:
# C:\Users\sande\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([333.31344272])

# %%
model.predict([[22.3,26.5,30.22,12.4,5.6]])
# Out:
# C:\Users\sande\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([342.54553355])

# %%
model.coef_
# Out:
# array([ 60.49545882, -13.07089713, -23.30185249,  27.73394198,
#         37.20033494])
